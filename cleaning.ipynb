# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 48.3 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 45.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas as pd

# Load the CSV file into a dataframe (tab-delimited)
df = pd.read_csv('full_data.csv', sep='\t')
df
# Out:
#        Ceremony     Year    Class  \
# 0             1  1927/28   Acting
# 1             1  1927/28   Acting
# 2             1  1927/28   Acting
# 3             1  1927/28   Acting
# 4             1  1927/28   Acting
# ...         ...      ...      ...
# 12009        97     2024  SciTech
# 12010        97     2024  SciTech
# 12011        97     2024  SciTech
# 12012        97     2024  SciTech
# 12013        97     2024  SciTech
#
#                                        CanonicalCategory  \
# 0                                ACTOR IN A LEADING ROLE
# 1                                ACTOR IN A LEADING ROLE
# 2                                ACTOR IN A LEADING ROLE
# 3                                ACTOR IN A LEADING ROLE
# 4                              ACTRESS IN A LEADING ROLE
# ...                                                  ...
# 12009  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12010  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# ...
